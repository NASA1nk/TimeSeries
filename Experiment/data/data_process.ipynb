# %%
# 查看KpiAnomaly目录下的数据
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import glob

files = glob.glob("./2018AIOpsData/*.csv")
cnt = len(files)
print(cnt)

for i, file in enumerate(files):
    df = pd.read_csv(file)
    name = file.split('/')[-1][:-4]
    marker = []
    for index, row in enumerate(df.loc[:,'label']):
        if row == 1:
            marker.append(index)
    fig, ax = plt.subplots(1, 1, figsize=(20, 10))
    fig.patch.set_facecolor('white')
    x = df["timestamp"]
    y = df["value"]
    ax.plot(x, y, marker='o', markerfacecolor = 'r', markevery=marker)
    ax.set_xlabel("timestamp")
    ax.set_ylabel("value")
    ax.set_title(f"{name}")
    plt.savefig(f'./2018AIOpsData/img/{name}.png')
# Out:
# 5

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv('./2018AIOpsData/kpi_1.csv')
marker = []
for index, row in enumerate(df.loc[4800:,'label']):
    if row == 1:
        marker.append(index)
        print(index,df.loc[index,'timestamp'],df.loc[index,'value'])
print(len(marker))
fig, ax = plt.subplots(1, 1, figsize=(20, 10))
fig.patch.set_facecolor('white')
x = df["timestamp"]
y = df["value"]
ax.plot(x, y, marker='o', markerfacecolor = 'r', markevery=marker)
ax.set_xlabel("timestamp")
ax.set_ylabel("value")
ax.set_title(f"{name}")
plt.show()
# Out:
# 42389 1496175600 47.75
# 42390 1496175660 44.25
# 42391 1496175720 45.75
# 42392 1496175780 45.8333320618
# 4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_19433/4089609557.py in <module>
#      18 ax.set_xlabel("timestamp")
#      19 ax.set_ylabel("value")
# ---> 20 ax.set_title(f"{name}")
#      21 plt.show()
#
# NameError: name 'name' is not defined

# %%
df = pd.read_csv('./2018AIOpsData/kpi_1.csv')
marker = []
df = df.loc[4800:]
df.head()
df.to_csv('./2018AIOpsData/kpi_normal_1.csv', index=None)

# %%
df = pd.read_csv('./2018AIOpsData/kpi_normal_1.csv')
print(df.shape)
marker = []
for index, row in enumerate(df['label']):
    if row == 1:
        marker.append(index)
        print(index,df.loc[index,'timestamp'],df.loc[index,'value'])
print(len(marker))
fig, ax = plt.subplots(1, 1, figsize=(20, 10))
fig.patch.set_facecolor('white')
x = df["timestamp"]
y = df["value"]
ax.plot(x, y, marker='o', markerfacecolor = 'r', markevery=marker)
ax.set_xlabel("timestamp")
ax.set_ylabel("value")
ax.set_title(f"{name}")
plt.show()
# Out:
# (123813, 4)
# 42389 1496569800 29.4166660309
# 42390 1496569860 5.33333349228
# 42391 1496569920 23.1666660309
# 42392 1496569980 34.1666679382
# 4

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv('./2018AIOpsData/kpi_normal_1.csv')
print(df.shape)
marker = []
for index, row in enumerate(df['label']):
    if row == 1:
        marker.append(index)
        print(index,df.loc[index,'timestamp'],df.loc[index,'value'])
print(len(marker))
fig, ax = plt.subplots(1, 1, figsize=(20, 10))
fig.patch.set_facecolor('white')
y = df["value"]
ax.plot(y, marker='o', markerfacecolor = 'r', markevery=marker)
ax.set_xlabel("timestamp")
ax.set_ylabel("value")
plt.show()
# Out:
# (123813, 4)
# 0

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv('./2018AIOpsData/kpi_normal_1.csv')
print(df.shape)
df = df.loc[90000:110000]
marker = []
for index, row in enumerate(df['label']):
    if row == 1:
        marker.append(index)
        print(index,df.loc[index,'timestamp'],df.loc[index,'value'])
print(len(marker))
fig, ax = plt.subplots(1, 1, figsize=(20, 10))
fig.patch.set_facecolor('white')
y = df["value"]
ax.plot(y, marker='o', markerfacecolor = 'r', markevery=marker)
ax.set_xlabel("timestamp")
ax.set_ylabel("value")
plt.show()
# Out:
# (123813, 4)
# 0

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv('./2018AIOpsData/kpi_normal_1.csv')
print(df.shape)
df = df.loc[110000:]
marker = []
for index, row in enumerate(df['label']):
    if row == 1:
        marker.append(index)
        print(index,df.loc[index,'timestamp'],df.loc[index,'value'])
print(len(marker))
fig, ax = plt.subplots(1, 1, figsize=(20, 10))
fig.patch.set_facecolor('white')
y = df["value"]
ax.plot(y, marker='o', markerfacecolor = 'r', markevery=marker)
ax.set_xlabel("timestamp")
ax.set_ylabel("value")
plt.show()
# Out:
# (123813, 4)
# 0

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv('./2018AIOpsData/kpi_normal_1.csv')
print(df.shape)
df = df.loc[123700:]
marker = []
for index, row in enumerate(df['label']):
    if row == 1:
        marker.append(index)
        print(index,df.loc[index,'timestamp'],df.loc[index,'value'])
print(len(marker))
fig, ax = plt.subplots(1, 1, figsize=(20, 10))
fig.patch.set_facecolor('white')
y = df["value"]
ax.plot(y, marker='o', markerfacecolor = 'r', markevery=marker)
ax.set_xlabel("timestamp")
ax.set_ylabel("value")
plt.show()
# Out:
# (123813, 4)
# 0

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv('./generate_time_data.csv')
print(df.shape)
fig, ax = plt.subplots(1, 1, figsize=(20, 10))
fig.patch.set_facecolor('white')
y = df[0:5000]["value"]
ax.plot(y)
ax.set_xlabel("timestamp")
ax.set_ylabel("value")
plt.show()
# Out:
# (7320000, 6)

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import date

data = pd.read_excel('./MultiTSData.xlsx', 'Sheet1', parse_dates=["date"])
data = data.loc[(data["date"] >= pd.Timestamp(date(2014, 1, 1))) & (data["date"] <= pd.Timestamp(date(2014, 2, 10)))]
data = data.loc[:, "MT_200":  "MT_209"]
data.head()
# Out:
#          MT_200      MT_201      MT_202      MT_203      MT_204      MT_205  \
# 135  319.383260  151.610865  200.000000  261.290323  447.761194  336.864407
# 136  362.334802  138.976627  170.140845  268.817204  389.552239  349.576271
# 137  342.511013  145.293746  158.873239  249.462366  362.686567  302.966102
# 138  343.612335  145.293746  145.352113  240.860215  392.537313  362.288136
# 139  339.207048  151.610865  149.859155  219.354839  382.089552  298.728814
#
#         MT_206      MT_207       MT_208    MT_209
# 135  72.737686  327.891156  3252.100840  265.6250
# 136  81.328751  334.693878  3210.084034  250.0000
# 137  73.310424  337.414966  3411.764706  265.6250
# 138  72.737686  355.102041  3453.781513  273.4375
# 139  69.873998  344.217687  3336.134454  257.8125

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv('./2018AIOpsData/kpi_1.csv')
df.shape
# Out:
# (128613, 4)

# %%
df1 = pd.read_csv('./2018AIOpsData/kpi_normal_1.csv')
df1.shape
# Out:
# (123813, 4)

# %%
df = pd.read_csv('./2018AIOpsData/kpi_12.csv')
print(df.shape)
marker = []
for index, row in enumerate(df['label']):
    if row == 1:
        marker.append(index)
        print(index,df.loc[index,'timestamp'],df.loc[index,'value'])
print(len(marker))
fig, ax = plt.subplots(1, 1, figsize=(80, 10))
fig.patch.set_facecolor('white')
x = df["timestamp"]
y = df["value"]
ax.plot(x, y, marker='o', markerfacecolor = 'r', markevery=marker)
ax.set_xlabel("timestamp")
ax.set_ylabel("value")
plt.show()
# Out:
# (8784, 4)
# 7341 1479440700 0.1035690877848136
# 7342 1479441000 0.1839335744682466
# 7343 1479441300 0.1061266407217745
# 7344 1479441600 0.12372343496565
# 4
